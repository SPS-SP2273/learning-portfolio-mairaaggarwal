# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %% [markdown]
# # A simple plot

# %% [markdown]
# ## Let’s look at some code.

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
# plt.spines['top'].set_visible(False)
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Things to note

# %%
plt.plot(x, y_1, color='red', linestyle='dashed', linewidth=2)

# %%
plt.plot(x, y_1, c='red', ls='dashed', lw=2)

# %%
plt.plot(x, y_1,'r--')

# %%
plt.plot(x,x)

# %%
plt.plot(x, y_1, y_2)

# %%
plt.plot(x, y_1, 
         c='red', 
         ls='dashed',
         lw=2)

# %% [markdown]
# ## Adding another plot

# %%
plt.plot(x, y_1, label='a', c='k')
plt.plot(x, y_2, label='b', c='k', ls='dashed')
plt.legend()

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='#f03b20', linestyle='dashed')
plt.plot(x, y_2, label='Y2 values', color='#31a354')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## Yet another plot but with error bars

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = 0.1, 0.75

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green', 
            alpha =.5)
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# # Better with NumPy

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
import math # math does not work

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2                  # The math stuff
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.grid(alpha=.25)
plt.legend()

# %% [markdown]
# ## We need another axis!

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x = np.arange(0,6,0.25)

x = np.linspace(0,6,100)

print(x)

x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc=(.25,.5), frameon=False)                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc=(.25,.45), frameon=False)                                 # For y-axis 2
# Out:
# [0.         0.06060606 0.12121212 0.18181818 0.24242424 0.3030303
#  0.36363636 0.42424242 0.48484848 0.54545455 0.60606061 0.66666667
#  0.72727273 0.78787879 0.84848485 0.90909091 0.96969697 1.03030303
#  1.09090909 1.15151515 1.21212121 1.27272727 1.33333333 1.39393939
#  1.45454545 1.51515152 1.57575758 1.63636364 1.6969697  1.75757576
#  1.81818182 1.87878788 1.93939394 2.         2.06060606 2.12121212
#  2.18181818 2.24242424 2.3030303  2.36363636 2.42424242 2.48484848
#  2.54545455 2.60606061 2.66666667 2.72727273 2.78787879 2.84848485
#  2.90909091 2.96969697 3.03030303 3.09090909 3.15151515 3.21212121
#  3.27272727 3.33333333 3.39393939 3.45454545 3.51515152 3.57575758
#  3.63636364 3.6969697  3.75757576 3.81818182 3.87878788 3.93939394
#  4.         4.06060606 4.12121212 4.18181818 4.24242424 4.3030303
#  4.36363636 4.42424242 4.48484848 4.54545455 4.60606061 4.66666667
#  4.72727273 4.78787879 4.84848485 4.90909091 4.96969697 5.03030303
# ...

# %% [markdown]
# ### Things to note

# %%
x = np.linspace(0, 6, 100)
x = np.arange(0,6,0.25)

# %% [markdown]
# # 3 Saving to disc

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed')
plt.legend(loc='lower left')
plt.twinx()
plt.plot(x, sin_x,
         label='sin x', color='blue')
plt.legend(loc='lower right')

plt.savefig('simple-plot.png', dpi=150)

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed')
plt.legend(loc='lower left')
plt.twinx()
plt.plot(x, sin_x,
         label='sin x', color='blue')
plt.legend(loc='lower right')

plt.savefig('simple-plot-transparent.png', dpi=10, transparent=True)

# %% [markdown]
# ![](simple-plot.png)

# %%
filename='spectrum-01.txt'
data=np.loadtxt(filename, skiprows=2)
x=data[:,0]
y=data[:,1]
plt.plot(x,y)

# %% [markdown]
# # A real example: Global Warming

# %% [markdown]
# ## Plotting data from files

# %%
plt.style.use('ggplot')

# %%
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=23)
year = data[:, 1]
anomaly = data[:, -1]
plt.hlines(0, year[0], year[-1], linestyle='--', colors='red')
plt.plot(year, anomaly, alpha=0.5)
plt.grid(alpha=0.25)
plt.savefig('avg_temp_graph')

# %%
plt.style.use('fivethirtyeight')

# %%
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=23)
date = data[:, 0]
anomaly = data[:, -1]
plt.hlines(0, year[0], year[-1], linestyle='--', colors='gray')
plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])
# Out:
# (-8.0, 8.0)

# %% [markdown]
# ## Styles

# %%
plt.style.use('dark_background')

# %%
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=23)
year = data[:, 1]
anomaly = data[:, -1]
plt.hlines(0, year[0], year[-1], linestyle='--', colors='red')
plt.plot(year, anomaly, alpha=0.5)
plt.grid(alpha=0.25)
plt.savefig('avg_temp_graph')

# %%
plt.plot(x,y)

# %% [markdown]
# ### xkcd!

# %%
plt.xkcd()

# %%
plt.plot(x,y)
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ...

# %% [markdown]
# ### Resetting styles

# %%
plt.style.use('default')
